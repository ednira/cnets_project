# %% [markdown]
# ## Demonstrating Object-centric Causal nets by Merging Different Object Types C-nets with a Running Example

# %% [markdown]
# This notebook shows a running example of the discovery and visualization of an Object-centric Casual nets as presented in the paper 'Towards Discovering Object-centric Causal-Nets'.

# %% [markdown]
# ### Pre-requisites

# %% [markdown]
# Please install the libraries mentioned in the file requirements.txt
# You can do it by using pip install -r requirements.txt

# %%
import pm4py
# import processmining

from discover_occnets import *
from view_occnets import *

# %%
file_path = './runningExample.sqlite'

# %% [markdown]
# ### Model Discovery

# %% [markdown]
# The approach introduced in the paper uses the discovery of Causal nets for each object type and then merges them. This running example is based on an order management process found in an OCEL 2.0 event log. First, let us view the process model when including all object types.

# %%
ocel, ot_activities, event_to_obj, obj_to_obj=import_log(file_path)
print(ot_activities)
flt = flatten_log(ocel, ot_activities)
#print(flt['Hinge'])
# Out:
# {'FemalePart': {'CuttFemalePart', 'AssembleHinge', 'CheckFemalePart'}, 'Hinge': {'AssembleHinge', 'PackHinges'}, 'Machine': {'PackHinges', 'HeatSteelSheet', 'CuttMalePart', 'CoatPart', 'CuttFemalePart', 'FormSteelSheet', 'AssembleHinge', 'SplitSteelSheet'}, 'MalePart': {'CheckMalePart', 'CuttMalePart', 'AssembleHinge'}, 'SteelPin': {'AssembleHinge'}, 'Workstation': {'CheckFemalePart', 'PackHinges', 'HeatSteelSheet', 'CuttMalePart', 'CoatPart', 'CuttFemalePart', 'FormSteelSheet', 'CheckMalePart', 'AssembleHinge', 'SplitSteelSheet'}, 'Worker': {'CheckMalePart', 'MoveParts', 'CheckFemalePart'}, 'FormedPart': {'CuttMalePart', 'CoatPart', 'CuttFemalePart', 'FormSteelSheet'}, 'SteelSheet': {'HeatSteelSheet', 'SplitSteelSheet', 'FormSteelSheet'}, 'Facility': {'MoveParts'}, 'HingePack': {'PackHinges'}, 'SteelCoil': {'SplitSteelSheet'}}
# ,ocel:eid,concept:name,time:timestamp,p_duration[s],s_co2e[kg],i_electric-from-grid-de[kWh],i_steel-waste-to-recycle[kg],i_gas_input[Wh],i_emission-of-burn[Wh],i_coating-material[kg],i_coating-material-waste[kg],i_compressed-air[m3],i_gas-n2-used[m3],i_gas-n2-emiited-to-air[m3],i_steel-waste[kg],i_cardboard-box[kg],case:concept:name,case:ocel:type,case:m_metadata,case:p_mass[kg],case:p_material[EN10130:2006],case:s_co2e[kg],case:i_steel-waste[kg],case:P_electric-from-grid-de[kWh],case:P_gas-from-grid-de[m3],case:p_init-len[cm],case:p_width[cm],case:i_material-cold-rolled-steel[kg],case:i_steel-waste-to-recycle[kg],case:i_material-steel-pin[kg],case:P_compressed-air[m3]
# 0,e_assembly_200,AssembleHinge,2023-04-03 08:56:50+00:00,5.0,?,,,,,,,,,,,,o_hinge_200,Hinge,,0.18501,DC01,0,,,,,,,,,
# 1,e_assembly_188,AssembleHinge,2023-04-03 08:57:12+00:00,5.0,?,,,,,,,,,,,,o_hinge_188,Hinge,,0.18579,DC01,0,,,,,,,,,
# 5805,e_assembly_5513,AssembleHinge,2023-04-06 16:01:30+00:00,5.0,?,,,,,,,,,,,,o_hinge_5513,Hinge,,0.18543,DC01,0,,,,,,,,,
# 5806,e_assembly_5380,AssembleHinge,2023-04-06 16:01:41+00:00,5.0,?,,,,,,,,,,,,o_hinge_5380,Hinge,,0.18557,DC01,0,,,,,,,,,

# %%
logs = read_log(flt)

# %%
all_traces = traces(flt)

# %%
ot1_ot2_cardinalities, ot2_ot1_cardinalities = ot_cardinalities(obj_to_obj, event_to_obj, ot_activities)

# %%
ot_seq = ot_sequence(ot_activities, ot1_ot2_cardinalities, ot2_ot1_cardinalities, event_to_obj)

ot_subgraphs_dict = {}

# %%
ot_activities, ot_seq, subgraphs = subgraphs_dict(file_path)

# %%
OCCN_model = all_ot_visualization(ot_activities, ot_seq, subgraphs)
# Out:
# Warning: transparent is not a known color.

# %% [markdown]
# Now, we illustrate how to discover Causal nets for an object type. Here, we choose the object type 'items'. These are the activities related to this object type.

# %%
print(ot_activities['items'])
# Out:
# {'pick item', 'place order', 'create package', 'package delivered', 'payment reminder', 'reorder item', 'send package', 'failed delivery', 'pay order', 'item out of stock', 'confirm order'}

# %% [markdown]
# First, we flatten and read the log. This allows us to have all activities related to the object type identified by the 'item' object ID and discover their traces, which is the sequence of activities for each object in the log. Let us see what the trace for item 'i-880001' looks like.

# %%
ocel, ot_activities, event_to_obj, obj_to_obj = import_log(file_path)
flt = flatten_log(ocel, ot_activities)
flt_items = flt['items']
logs = read_log(flt)
logs_items = logs['items']
all_traces = traces(flt)
ot_traces = all_traces['items']

# %% [markdown]
# Let us see how the trace for item 'i-880001' looks like.

# %%
print(ot_traces['i-880001'])
# Out:
# ['place order', 'pick item', 'confirm order', 'pay order', 'create package', 'send package', 'package delivered']

# %% [markdown]
# It shows all activities realized for item 'i-880001' in the order in which they happened. This is possible due to activity timestamps in the log. Next, we want to count some frequencies. As shown in the model, each activity has its corresponding total count. Also, the frequency one activity is followed by another activity is counted because it allows us to calculate the dependency between them. In addition, we discover the start and end activities for the object type 'items'.

# %%
act_total = activity_total(logs['items'])
activities = activity_frequencies(logs_items)
or_start = original_start(act_total, activities)
or_end = original_end(act_total, activities)
freq = frequencies(activities)

# %% [markdown]
# Let us check how the frequency matrix for object type 'items' looks like.

# %%
print()
print('FREQUENCY MATRIX')
print()
print(freq)
# Out:
# FREQUENCY MATRIX
#
#                    pick item  confirm order  item out of stock  place order  \
# place order             35.0          118.0                6.0          0.0
# pick item                0.0           34.0                0.0          0.0
# confirm order           85.0            0.0               20.0          0.0
# pay order                8.0            0.0                0.0          0.0
# create package           1.0            0.0                0.0          0.0
# reorder item             9.0            1.0                0.0          0.0
# send package             0.0            1.0                0.0          0.0
# item out of stock        0.0            5.0                0.0          0.0
# package delivered        0.0            0.0                0.0          0.0
# payment reminder         0.0            0.0                0.0          0.0
# failed delivery          0.0            0.0                0.0          0.0
#
#                    payment reminder  create package  pay order  send package  \
# place order                     0.0             0.0        0.0           0.0
# pick item                       1.0            54.0       24.0           1.0
# confirm order                   0.0            18.0       20.0           0.0
# pay order                       0.0            27.0        0.0           0.0
# create package                  0.0             0.0        0.0          94.0
# reorder item                    0.0             0.0        7.0           0.0
# send package                    0.0             0.0        7.0           0.0
# item out of stock               0.0             0.0        2.0           0.0
# package delivered               5.0             0.0        7.0           0.0
# payment reminder                0.0             0.0        0.0           0.0
# failed delivery                 0.0             0.0        7.0           0.0
#
#                    reorder item  package delivered  failed delivery
# place order                 0.0                0.0              0.0
# pick item                   0.0                0.0              0.0
# confirm order               4.0                0.0              0.0
# pay order                   3.0               14.0              0.0
# create package              0.0                0.0              0.0
# reorder item                0.0                0.0              0.0
# send package                0.0               46.0             30.0
# item out of stock          18.0                0.0              0.0
# package delivered           0.0                0.0              0.0
# payment reminder            0.0                0.0              0.0
# failed delivery             0.0               23.0             14.0

# %% [markdown]
# Now, we can proceed to calculate the dependencies between activities. If only frequency were considered, noise in the log could influence it, causing underfitting and admitting more behavior than it should in the model. However, the dependency measures prevent this from happening and are the fundamental variables on which Causal nets rely. We use three formulas to calculate the dependency measures. The first one relates two activities to one another; the second one relates one activity to itself (loops); and the third one relates two non-consecutive activities and helps determine if there is a long-distance causal relation between them. Let us see the dependency matrix for the object type 'items'.

# %%
dep = dependency_matrix(freq)
dep_dict = dependency_dict(dep)
long = long_distance_dependency(act_total, ot_traces, or_start, or_end)
print()
print('DEPENDENCY MATRIX')
print()
print(dep)
# Out:
# DEPENDENCY MATRIX
#
#                   pick item confirm order item out of stock place order  \
# place order        0.972222      0.991597          0.857143         0.0
# pick item               0.0        -0.425               0.0   -0.972222
# confirm order         0.425           0.0          0.576923   -0.991597
# pay order         -0.484848     -0.952381         -0.666667         0.0
# create package    -0.946429     -0.947368               0.0         0.0
# reorder item            0.9          -0.5         -0.947368         0.0
# send package           -0.5           0.5               0.0         0.0
# item out of stock       0.0     -0.576923               0.0   -0.857143
# package delivered       0.0           0.0               0.0         0.0
# payment reminder       -0.5           0.0               0.0         0.0
# failed delivery         0.0           0.0               0.0         0.0
#
#                   payment reminder create package pay order send package  \
# place order                    0.0            0.0       0.0          0.0
# pick item                      0.5       0.946429  0.484848          0.5
# confirm order                  0.0       0.947368  0.952381         -0.5
# pay order                      0.0       0.964286       0.0       -0.875
# create package                 0.0            0.0 -0.964286     0.989474
# reorder item                   0.0            0.0  0.363636          0.0
# send package                   0.0      -0.989474     0.875          0.0
# item out of stock              0.0            0.0  0.666667          0.0
# package delivered         0.833333            0.0 -0.318182    -0.978723
# payment reminder               0.0            0.0       0.0          0.0
# failed delivery                0.0            0.0     0.875    -0.967742
#
#                   reorder item package delivered failed delivery
# place order                0.0               0.0             0.0
# pick item                 -0.9               0.0             0.0
# confirm order              0.5               0.0             0.0
# pay order            -0.363636          0.318182          -0.875
# create package             0.0               0.0             0.0
# reorder item               0.0               0.0             0.0
# send package               0.0          0.978723        0.967742
# item out of stock     0.947368               0.0             0.0
# package delivered          0.0               0.0       -0.958333
# payment reminder           0.0         -0.833333             0.0
# failed delivery            0.0          0.958333        0.933333

# %% [markdown]
# We consider a dependency measure of 0.95 or higher to build the dependency graph that serves as basis for the model. The dependency graph is composed of nodes and edges, where the nodes are the activities, and the edges are the arcs that connect one activity to another, showing the frequency and dependency relationships between them. When building the dependency graph, we need to avoid disconnected activities in the Causal nets model. This is achieved for each object type, but it is not always possible when there is more than one object type in the model because each object type has different start and end activities. To find the predecessor and successor activities of each activity, the dependency measure threshold is considered. This results in activities losing the race and potentially being disconnected in the Causal nets of an object type. To solve this, the next best predecessor is mined.

# %%
depgraph = dependency_graph(act_total, or_start, or_end, freq, dep, dep_dict, long, dependency_threshold=0.95)

# %% [markdown]
# Next, we use the dependency graph edges to discover the input and output arcs, that is, the predecessor and successor activities of each activity. By replaying the log in the arcs, we find the input and output bindings of each activity. This is the last step we need to take to discover the Causal nets of an object type.

# %%
# Generate the arcs based on the edges of the dep_graph
in_arcs = input_arcs(depgraph)
out_arcs = output_arcs(depgraph)

# Find the bindings in the incoming and outgoing arcs of the graph, using replay
cnet_outbindings = output_bindings(ot_traces, out_arcs, in_arcs)
cnet_inbindings = input_bindings(ot_traces, out_arcs, in_arcs)

# %% [markdown]
# Let us discover the Causal nets of the object type 'items'.

# %%
ot_nodes, ot_edges, i_seq, o_seq = ot_graph(depgraph, act_total, activities, dep_dict, cnet_inbindings, cnet_outbindings, seq_i=1, seq_o=1)
ot_subgraphs_dict = {'items': (ot_nodes, ot_edges)}
print(ot_subgraphs_dict)
# Out:
# {'items': (                 node        type             source             target  \
# 0         place order    activity                NaN                NaN
# 1           pick item    activity                NaN                NaN
# 2       confirm order    activity                NaN                NaN
# 3           pay order    activity                NaN                NaN
# 4      create package    activity                NaN                NaN
# 5        send package    activity                NaN                NaN
# 6   package delivered    activity                NaN                NaN
# 7   item out of stock    activity                NaN                NaN
# 8        reorder item    activity                NaN                NaN
# 9    payment reminder    activity                NaN                NaN
# 10    failed delivery    activity                NaN                NaN
# 11                o_1  outbinding        place order      confirm order
# 12                o_2  outbinding        place order          pick item
# 13                o_3  outbinding        place order      confirm order
# 14                o_4  outbinding        place order  item out of stock
# 15                o_5  outbinding        place order      confirm order
# 16                o_6  outbinding          pick item     create package
# 17                o_7  outbinding      confirm order          pay order
# 18                o_8  outbinding          pay order     create package
# 19                o_9  outbinding     create package       send package
# 20               o_10  outbinding       send package  package delivered
# 21               o_11  outbinding       send package    failed delivery
# 22               o_12  outbinding  package delivered   payment reminder
# 23               o_13  outbinding  item out of stock       reorder item
# 24               o_14  outbinding       reorder item          pick item
# 25               o_15  outbinding    failed delivery  package delivered
# 26                i_1   inbinding        place order          pick item
# 27                i_2   inbinding       reorder item          pick item
# 28                i_3   inbinding        place order      confirm order
# 29                i_4   inbinding      confirm order          pay order
# 30                i_5   inbinding          pay order     create package
# 31                i_6   inbinding          pick item     create package
# 32                i_7   inbinding          pick item     create package
# 33                i_8   inbinding          pay order     create package
# 34                i_9   inbinding     create package       send package
# 35               i_10   inbinding       send package  package delivered
# 36               i_11   inbinding    failed delivery  package delivered
# 37               i_12   inbinding        place order  item out of stock
# 38               i_13   inbinding  item out of stock       reorder item
# 39               i_14   inbinding  package delivered   payment reminder
# 40               i_15   inbinding       send package    failed delivery
#
#                                binding  len_binding  \
# 0                                  NaN          NaN
# 1                                  NaN          NaN
# 2                                  NaN          NaN
# 3                                  NaN          NaN
# 4                                  NaN          NaN
# 5                                  NaN          NaN
# 6                                  NaN          NaN
# 7                                  NaN          NaN
# 8                                  NaN          NaN
# 9                                  NaN          NaN
# 10                                 NaN          NaN
# 11          (confirm order, pick item)          2.0
# 12          (confirm order, pick item)          2.0
# 13  (confirm order, item out of stock)          2.0
# 14  (confirm order, item out of stock)          2.0
# 15                    (confirm order,)          1.0
# 16                   (create package,)          1.0
# 17                        (pay order,)          1.0
# 18                   (create package,)          1.0
# 19                     (send package,)          1.0
# 20                (package delivered,)          1.0
# 21                  (failed delivery,)          1.0
# 22                 (payment reminder,)          1.0
# 23                     (reorder item,)          1.0
# 24                        (pick item,)          1.0
# 25                (package delivered,)          1.0
# 26                      (place order,)          1.0
# 27                     (reorder item,)          1.0
# 28                      (place order,)          1.0
# 29                    (confirm order,)          1.0
# 30              (pay order, pick item)          2.0
# 31              (pay order, pick item)          2.0
# 32                        (pick item,)          1.0
# 33                        (pay order,)          1.0
# 34                   (create package,)          1.0
# 35                     (send package,)          1.0
# 36                  (failed delivery,)          1.0
# 37                      (place order,)          1.0
# 38                (item out of stock,)          1.0
# 39                (package delivered,)          1.0
# 40                     (send package,)          1.0
#
#                                                 label act_total    color  \
# 0   <<FONT>place order</FONT><BR/><FONT POINT-SIZE...       168  #97c2fc
# 1   <<FONT>pick item</FONT><BR/><FONT POINT-SIZE="...       138  #97c2fc
# 2   <<FONT>confirm order</FONT><BR/><FONT POINT-SI...       159  #97c2fc
# 3   <<FONT>pay order</FONT><BR/><FONT POINT-SIZE="...        74  #97c2fc
# 4   <<FONT>create package</FONT><BR/><FONT POINT-S...        99  #97c2fc
# 5   <<FONT>send package</FONT><BR/><FONT POINT-SIZ...        95  #97c2fc
# 6   <<FONT>package delivered</FONT><BR/><FONT POIN...        83  #97c2fc
# 7   <<FONT>item out of stock</FONT><BR/><FONT POIN...        26  #97c2fc
# 8   <<FONT>reorder item</FONT><BR/><FONT POINT-SIZ...        25  #97c2fc
# 9   <<FONT>payment reminder</FONT><BR/><FONT POINT...         6  #97c2fc
# 10  <<FONT>failed delivery</FONT><BR/><FONT POINT-...        44  #97c2fc
# 11                                               None       NaN    black
# 12                                               None       NaN    black
# 13                                               None       NaN    black
# 14                                               None       NaN    black
# 15                                                  8       NaN    black
# 16                                                 71       NaN    black
# 17                                                 74       NaN    black
# 18                                                 27       NaN    black
# 19                                                 95       NaN    black
# 20                                                 53       NaN    black
# 21                                                 30       NaN    black
# 22                                                  5       NaN    black
# 23                                                 25       NaN    black
# 24                                                 13       NaN    black
# 25                                                 30       NaN    black
# 26                                                 35       NaN    black
# 27                                                 13       NaN    black
# 28                                                118       NaN    black
# 29                                                 74       NaN    black
# 30                                               None       NaN    black
# 31                                               None       NaN    black
# 32                                                 66       NaN    black
# 33                                                 21       NaN    black
# 34                                                 95       NaN    black
# 35                                                 53       NaN    black
# 36                                                 30       NaN    black
# 37                                                  6       NaN    black
# 38                                                 25       NaN    black
# 39                                                  5       NaN    black
# 40                                                 30       NaN    black
#
#    intensity    shape  size                                        obj_group
# 0        NaN      box   2.0                                              NaN
# 1        NaN      box   2.0                                              NaN
# 2        NaN      box   2.0                                              NaN
# 3        NaN      box   2.0                                              NaN
# 4        NaN      box   2.0                                              NaN
# 5        NaN      box   2.0                                              NaN
# 6        NaN      box   2.0                                              NaN
# 7        NaN      box   2.0                                              NaN
# 8        NaN      box   2.0                                              NaN
# 9        NaN      box   2.0                                              NaN
# 10       NaN      box   2.0                                              NaN
# 11       NaN    point   0.7                  out place order - confirm order
# 12       NaN    point   0.7                      out place order - pick item
# 13       NaN    point   0.7                  out place order - confirm order
# 14       NaN    point   0.7              out place order - item out of stock
# 15       NaN    point   0.7           out single place order - confirm order
# 16       NaN    point   0.7            out single pick item - create package
# 17       NaN    point   0.7             out single confirm order - pay order
# 18       NaN    point   0.7            out single pay order - create package
# 19       NaN    point   0.7         out single create package - send package
# 20       NaN    point   0.7      out single send package - package delivered
# 21       NaN    point   0.7        out single send package - failed delivery
# 22       NaN    point   0.7  out single package delivered - payment reminder
# 23       NaN    point   0.7      out single item out of stock - reorder item
# 24       NaN    point   0.7              out single reorder item - pick item
# 25       NaN    point   0.7   out single failed delivery - package delivered
# 26      None  diamond   0.7               out single pick item - place order
# 27      None  diamond   0.7              out single pick item - reorder item
# 28      None  diamond   0.7           out single confirm order - place order
# 29      None  diamond   0.7             out single pay order - confirm order
# 30      None  diamond   0.7                   out create package - pay order
# 31      None  diamond   0.7                   out create package - pick item
# 32      None  diamond   0.7            out single create package - pick item
# 33      None  diamond   0.7            out single create package - pay order
# 34      None  diamond   0.7         out single send package - create package
# 35      None  diamond   0.7      out single package delivered - send package
# 36      None  diamond   0.7   out single package delivered - failed delivery
# 37      None  diamond   0.7       out single item out of stock - place order
# 38      None  diamond   0.7      out single reorder item - item out of stock
# 39      None  diamond   0.7  out single payment reminder - package delivered
# 40      None  diamond   0.7        out single failed delivery - send package  ,                          original_edge             source             target  \
# 0              confirm order pay order      confirm order                o_7
# 1              confirm order pay order                o_7                i_4
# 2              confirm order pay order                i_4          pay order
# 3          create package send package     create package                o_9
# 4          create package send package                o_9                i_9
# 5          create package send package                i_9       send package
# 6    failed delivery package delivered    failed delivery               o_15
# 7    failed delivery package delivered               o_15               i_11
# 8    failed delivery package delivered               i_11  package delivered
# 9       item out of stock reorder item  item out of stock               o_13
# 10      item out of stock reorder item               o_13               i_13
# 11      item out of stock reorder item               i_13       reorder item
# 12  package delivered payment reminder  package delivered               o_12
# 13  package delivered payment reminder               o_12               i_14
# 14  package delivered payment reminder               i_14   payment reminder
# 15            pay order create package          pay order                o_8
# 16            pay order create package                o_8                i_5
# 17            pay order create package                i_5                i_8
# 18            pay order create package                i_8     create package
# 19            pick item create package          pick item                o_6
# 20            pick item create package                o_6                i_6
# 21            pick item create package                i_6                i_7
# 22            pick item create package                i_7     create package
# 23           place order confirm order        place order                o_5
# 24           place order confirm order                o_5                o_1
# 25           place order confirm order                o_1                o_3
# 26           place order confirm order                o_3                i_3
# 27           place order confirm order                i_3      confirm order
# 28       place order item out of stock        place order                o_4
# 29       place order item out of stock                o_4               i_12
# 30       place order item out of stock               i_12  item out of stock
# 31               place order pick item        place order                o_2
# 32               place order pick item                o_2                i_1
# 33               place order pick item                i_1          pick item
# 34              reorder item pick item       reorder item               o_14
# 35              reorder item pick item               o_14                i_2
# 36              reorder item pick item                i_2          pick item
# 37        send package failed delivery       send package               o_11
# 38        send package failed delivery               o_11               i_15
# 39        send package failed delivery               i_15    failed delivery
# 40      send package package delivered       send package               o_10
# 41      send package package delivered               o_10               i_10
# 42      send package package delivered               i_10  package delivered
# 43                                None                o_3                o_4
# 44                                None                o_1                o_2
# 45                                None                i_5                i_6
#
#                       label           type  color intensity width  length  \
# 0                            visualization  black      None  None     1.0
# 1    freq = 20 / dep = 0.95  visualization  black      None  None     4.0
# 2                            visualization  black      None  None     1.0
# 3                            visualization  black      None  None     1.0
# 4    freq = 94 / dep = 0.99  visualization  black      None  None     4.0
# 5                            visualization  black      None  None     1.0
# 6                            visualization  black      None  None     1.0
# 7    freq = 23 / dep = 0.96  visualization  black      None  None     4.0
# 8                            visualization  black      None  None     1.0
# 9                            visualization  black      None  None     1.0
# 10   freq = 18 / dep = 0.95  visualization  black      None  None     4.0
# 11                           visualization  black      None  None     1.0
# 12                           visualization  black      None  None     1.0
# 13    freq = 5 / dep = 0.83  visualization  black      None  None     4.0
# 14                           visualization  black      None  None     1.0
# 15                           visualization  black      None  None     1.0
# 16   freq = 27 / dep = 0.96  visualization  black      None  None     4.0
# 17                           visualization  black      None  None     1.0
# 18                           visualization  black      None  None     1.0
# 19                           visualization  black      None  None     1.0
# 20   freq = 54 / dep = 0.95  visualization  black      None  None     4.0
# 21                           visualization  black      None  None     1.0
# 22                           visualization  black      None  None     1.0
# 23                           visualization  black      None  None     1.0
# 24                           visualization  black      None  None     1.0
# 25                           visualization  black      None  None     1.0
# 26  freq = 118 / dep = 0.99  visualization  black      None  None     4.0
# 27                           visualization  black      None  None     1.0
# 28                           visualization  black      None  None     1.0
# 29    freq = 6 / dep = 0.86  visualization  black      None  None     4.0
# 30                           visualization  black      None  None     1.0
# 31                           visualization  black      None  None     1.0
# 32   freq = 35 / dep = 0.97  visualization  black      None  None     4.0
# 33                           visualization  black      None  None     1.0
# 34                           visualization  black      None  None     1.0
# 35    freq = 9 / dep = 0.90  visualization  black      None  None     4.0
# 36                           visualization  black      None  None     1.0
# 37                           visualization  black      None  None     1.0
# 38   freq = 30 / dep = 0.97  visualization  black      None  None     4.0
# 39                           visualization  black      None  None     1.0
# 40                           visualization  black      None  None     1.0
# 41   freq = 46 / dep = 0.98  visualization  black      None  None     4.0
# 42                           visualization  black      None  None     1.0
# 43                       26    vis_binding  black      None  None     NaN
# 44                      125    vis_binding  black      None  None     NaN
# 45                       33    vis_binding  black      None  None     NaN
#
#    object_relation  arrow
# 0            start  False
# 1           middle  False
# 2              end   True
# 3            start  False
# 4           middle  False
# 5              end   True
# 6            start  False
# 7           middle  False
# 8              end   True
# 9            start  False
# 10          middle  False
# 11             end   True
# 12           start  False
# 13          middle  False
# 14             end   True
# 15           start  False
# 16          middle  False
# 17      continue_i  False
# 18             end   True
# 19           start  False
# 20          middle  False
# 21      continue_i  False
# 22             end   True
# 23           start  False
# 24      continue_o  False
# 25      continue_o  False
# 26          middle  False
# 27             end   True
# 28           start  False
# 29          middle  False
# 30             end   True
# 31           start  False
# 32          middle  False
# 33             end   True
# 34           start  False
# 35          middle  False
# 36             end   True
# 37           start  False
# 38          middle  False
# 39             end   True
# 40           start  False
# 41          middle  False
# 42             end   True
# 43       binding_o    NaN
# 44       binding_o    NaN
# 45       binding_i    NaN  )}

# %% [markdown]
# However, this tabular representation is not ideal. So, in the next section, we will graphically visualize the complete model for selected object types.

# %% [markdown]
# ### Model Visualization

# %% [markdown]
# We start by visualizing the 'items' object type Causal nets discovered in the previous section.

# %%
profile=['items']
cnets_items = all_ot_visualization(ot_activities, ot_seq, subgraphs, profile=profile)
# Out:
# Warning: transparent is not a known color.

# %% [markdown]
# It is good to visualize the Causal nets graphically. However, in object-centric process mining, we are interested in the relationships between different object types. If all object types are included, the model can become cluttered and hinder the analysis. Thus, we select some object types, and their Causal nets are discovered and then merged to be presented in the model. The object types and respective activities for the current process are presented here.

# %%
for k,v in ot_activities.items():
    print(f"OT '{k}': activities {v}")  
print()
# Out:
# OT 'customers': activities {'place order', 'confirm order'}
# OT 'employees': activities {'pick item', 'create package', 'package delivered', 'reorder item', 'send package', 'failed delivery', 'item out of stock', 'confirm order'}
# OT 'items': activities {'pick item', 'place order', 'create package', 'package delivered', 'payment reminder', 'reorder item', 'send package', 'failed delivery', 'pay order', 'item out of stock', 'confirm order'}
# OT 'orders': activities {'place order', 'confirm order', 'payment reminder', 'pay order'}
# OT 'products': activities {'pick item', 'place order', 'create package', 'package delivered', 'payment reminder', 'reorder item', 'send package', 'failed delivery', 'pay order', 'item out of stock', 'confirm order'}
# OT 'packages': activities {'send package', 'create package', 'package delivered', 'failed delivery'}

# %% [markdown]
# To generate the model, we can define a profile, which is the list of object types we select to include in the visualization. If not defined, the model will include all object types encountered in the OCEL file. In our case, the profile is ['items', 'packages']. Note that activities {'package delivered', 'send package', 'create package', 'failed delivery'} are common to both object types. This would result in more than one edge connecting two activities, one for each object type. To solve this, edges are merged to be represented in the model, and the frequency and dependency measures of one activity followed by another are shown in different colors assigned to each object type, for clarity. This is done only for single bindings, as explained in the paper. Next, the nodes of merged edges are removed from the graph in the algorithm. The final step is to generate the model and the legend for visualization. In our case, the chosen profile generates the following model.

# %%
profile = ['items', 'packages']

# %%
OCCN_model = all_ot_visualization(ot_activities, ot_seq, subgraphs, profile=profile)
# Out:
# Warning: transparent is not a known color.
