# %% [markdown]
# ## Demonstrating Object-centric Causal nets by Merging Different Object Types C-nets with a Running Example

# %% [markdown]
# This notebook shows a running example of the discovery and visualization of an Object-centric Casual nets as presented in the paper 'Discovering Minimal Object-Centric Causal-Nets in Process Mining'.

# %% [markdown]
# ### Pre-requisites

# %% [markdown]
# Please install the libraries mentioned in the file requirements.txt
# <br>You can do it by using pip install -r requirements.txt

# %%
import pm4py

from discover_occnets import *
from view_occnets_jupyter import *

# %%
file_path = './order-management.json'

# %%
ocel, ot_activities, event_to_obj, obj_to_obj = import_log(file_path)

# %% [markdown]
# ### Model Discovery

# %% [markdown]
# The approach introduced in the paper uses the discovery of Causal nets for each object type and then merges them. This running example is based on an order management process found in an OCEL 2.0 event log. First, let us view the process model when including all object types.

# %%
ot_activities, subgraphs, ot_edges = subgraphs_dict(file_path, dependency_threshold=0.99)

# %%
grouped_df = ot_edges.groupby('original_edge')
for key, item in grouped_df:
    print(grouped_df.get_group(key), "\n\n")
# Out:
#                    original_edge         source         target  \
# 0    confirm order confirm order  confirm order            o_2
# 1    confirm order confirm order            o_2            i_2
# 2    confirm order confirm order            i_2  confirm order
# 6    confirm order confirm order  confirm order            o_8
# 7    confirm order confirm order            o_8            i_8
# 8    confirm order confirm order            i_8  confirm order
# 112  confirm order confirm order  confirm order           o_36
# 113  confirm order confirm order           o_36           i_42
# 114  confirm order confirm order           i_42  confirm order
#
#                         label           type  color intensity width  length  \
# 0                              visualization  black      None  None     1.0
# 1     freq = 505 / dep = 1.00  visualization  black      None  None     4.0
# 2                              visualization  black      None  None     1.0
# 6                              visualization  black      None  None     1.0
# 7    freq = 1995 / dep = 1.00  visualization  black      None  None     4.0
# 8                              visualization  black      None  None     1.0
# 112                            visualization  black      None  None     1.0
# 113   freq = 730 / dep = 1.00  visualization  black      None  None     4.0
# 114                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 0             start  False   customers
# 1            middle  False   customers
# 2               end   True   customers
# 6             start  False   employees
# 7            middle  False   employees
# 8               end   True   employees
# 112           start  False    products
# 113          middle  False    products
# 114             end   True    products
#
#
#               original_edge         source     target  \
# 30  confirm order pay order  confirm order       o_17
# 31  confirm order pay order           o_17       i_15
# 32  confirm order pay order           i_15       i_14
# 33  confirm order pay order           i_14  pay order
# 95  confirm order pay order  confirm order       o_30
# 96  confirm order pay order           o_30       i_35
# 97  confirm order pay order           i_35  pay order
#
#                        label           type  color intensity width  length  \
# 30                            visualization  black      None  None     1.0
# 31  freq = 1363 / dep = 1.00  visualization  black      None  None     4.0
# 32                            visualization  black      None  None     1.0
# 33                            visualization  black      None  None     1.0
# 95                            visualization  black      None  None     1.0
# 96  freq = 1557 / dep = 1.00  visualization  black      None  None     4.0
# 97                            visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 30           start  False       items
# 31          middle  False       items
# 32      continue_i  False       items
# 33             end   True       items
# 95           start  False      orders
# 96          middle  False      orders
# 97             end   True      orders
#
#
#                       original_edge         source            target  \
# 98   confirm order payment reminder  confirm order              o_31
# 99   confirm order payment reminder           o_31              i_37
# 100  confirm order payment reminder           i_37  payment reminder
#
#                        label           type  color intensity width  length  \
# 98                            visualization  black      None  None     1.0
# 99   freq = 443 / dep = 1.00  visualization  black      None  None     4.0
# 100                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 98            start  False      orders
# 99           middle  False      orders
# 100             end   True      orders
#
#
#                      original_edge          source          target  \
# 9    create package create package  create package             o_7
# 10   create package create package             o_7             i_7
# 11   create package create package             i_7  create package
# 115  create package create package  create package            o_40
# 116  create package create package            o_40            i_46
# 117  create package create package            i_46  create package
#
#                        label           type  color intensity width  length  \
# 9                             visualization  black      None  None     1.0
# 10    freq = 72 / dep = 0.99  visualization  black      None  None     4.0
# 11                            visualization  black      None  None     1.0
# 115                           visualization  black      None  None     1.0
# 116  freq = 298 / dep = 1.00  visualization  black      None  None     4.0
# 117                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 9             start  False   employees
# 10           middle  False   employees
# 11              end   True   employees
# 115           start  False    products
# 116          middle  False    products
# 117             end   True    products
#
#
#                    original_edge          source        target  \
# 34   create package send package  create package          o_19
# 35   create package send package            o_19          i_22
# 36   create package send package            i_22          i_21
# 37   create package send package            i_21  send package
# 145  create package send package  create package          o_45
# 146  create package send package            o_45          i_51
# 147  create package send package            i_51  send package
#
#                         label           type  color intensity width  length  \
# 34                             visualization  black      None  None     1.0
# 35   freq = 7100 / dep = 1.00  visualization  black      None  None     4.0
# 36                             visualization  black      None  None     1.0
# 37                             visualization  black      None  None     1.0
# 145                            visualization  black      None  None     1.0
# 146  freq = 1128 / dep = 1.00  visualization  black      None  None     4.0
# 147                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 34            start  False       items
# 35           middle  False       items
# 36       continue_i  False       items
# 37              end   True       items
# 145           start  False    packages
# 146          middle  False    packages
# 147             end   True    packages
#
#
#                        original_edge           source           target  \
# 12   failed delivery failed delivery  failed delivery             o_10
# 13   failed delivery failed delivery             o_10             i_10
# 14   failed delivery failed delivery             i_10  failed delivery
# 38   failed delivery failed delivery  failed delivery             o_28
# 39   failed delivery failed delivery             o_28             i_31
# 40   failed delivery failed delivery             i_31             i_33
# 41   failed delivery failed delivery             i_33  failed delivery
# 118  failed delivery failed delivery  failed delivery             o_43
# 119  failed delivery failed delivery             o_43             i_49
# 120  failed delivery failed delivery             i_49  failed delivery
#
#                        label           type  color intensity width  length  \
# 12                            visualization  black      None  None     1.0
# 13    freq = 67 / dep = 0.99  visualization  black      None  None     4.0
# 14                            visualization  black      None  None     1.0
# 38                            visualization  black      None  None     1.0
# 39   freq = 617 / dep = 1.00  visualization  black      None  None     4.0
# 40                            visualization  black      None  None     1.0
# 41                            visualization  black      None  None     1.0
# 118                           visualization  black      None  None     1.0
# 119  freq = 104 / dep = 0.99  visualization  black      None  None     4.0
# 120                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 12            start  False   employees
# 13           middle  False   employees
# 14              end   True   employees
# 38            start  False       items
# 39           middle  False       items
# 40       continue_i  False       items
# 41              end   True       items
# 118           start  False    products
# 119          middle  False    products
# 120             end   True    products
#
#
#                          original_edge           source             target  \
# 42   failed delivery package delivered  failed delivery               o_27
# 43   failed delivery package delivered             o_27               i_25
# 44   failed delivery package delivered             i_25  package delivered
# 148  failed delivery package delivered  failed delivery               o_48
# 149  failed delivery package delivered             o_48               i_53
# 150  failed delivery package delivered             i_53  package delivered
#
#                         label           type  color intensity width  length  \
# 42                             visualization  black      None  None     1.0
# 43   freq = 1319 / dep = 1.00  visualization  black      None  None     4.0
# 44                             visualization  black      None  None     1.0
# 148                            visualization  black      None  None     1.0
# 149   freq = 214 / dep = 1.00  visualization  black      None  None     4.0
# 150                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 42            start  False       items
# 43           middle  False       items
# 44              end   True       items
# 148           start  False    packages
# 149          middle  False    packages
# 150             end   True    packages
#
#
#                            original_edge             source  \
# 15   item out of stock item out of stock  item out of stock
# 16   item out of stock item out of stock                o_5
# 17   item out of stock item out of stock                i_5
# 121  item out of stock item out of stock  item out of stock
# 122  item out of stock item out of stock               o_38
# 123  item out of stock item out of stock               i_44
#
#                 target                    label           type  color  \
# 15                 o_5                           visualization  black
# 16                 i_5  freq = 192 / dep = 0.99  visualization  black
# 17   item out of stock                           visualization  black
# 121               o_38                           visualization  black
# 122               i_44   freq = 40 / dep = 0.98  visualization  black
# 123  item out of stock                           visualization  black
#
#     intensity width  length object_relation  arrow object_type
# 15       None  None     1.0           start  False   employees
# 16       None  None     4.0          middle  False   employees
# 17       None  None     1.0             end   True   employees
# 121      None  None     1.0           start  False    products
# 122      None  None     4.0          middle  False    products
# 123      None  None     1.0             end   True    products
#
#
#                      original_edge             source        target  \
# 45  item out of stock reorder item  item out of stock          o_23
# 46  item out of stock reorder item               o_23          i_27
# 47  item out of stock reorder item               i_27  reorder item
#
#                        label           type  color intensity width  length  \
# 45                            visualization  black      None  None     1.0
# 46  freq = 1078 / dep = 1.00  visualization  black      None  None     4.0
# 47                            visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 45           start  False       items
# 46          middle  False       items
# 47             end   True       items
#
#
#                            original_edge             source  \
# 18   package delivered package delivered  package delivered
# 19   package delivered package delivered                o_9
# 20   package delivered package delivered                i_9
# 124  package delivered package delivered  package delivered
# 125  package delivered package delivered               o_42
# 126  package delivered package delivered               i_48
#
#                 target                    label           type  color  \
# 18                 o_9                           visualization  black
# 19                 i_9  freq = 268 / dep = 1.00  visualization  black
# 20   package delivered                           visualization  black
# 124               o_42                           visualization  black
# 125               i_48  freq = 687 / dep = 1.00  visualization  black
# 126  package delivered                           visualization  black
#
#     intensity width  length object_relation  arrow object_type
# 18       None  None     1.0           start  False   employees
# 19       None  None     4.0          middle  False   employees
# 20       None  None     1.0             end   True   employees
# 124      None  None     1.0           start  False    products
# 125      None  None     4.0          middle  False    products
# 126      None  None     1.0             end   True    products
#
#
#                          original_edge             source            target  \
# 48  package delivered payment reminder  package delivered              o_22
# 49  package delivered payment reminder               o_22              i_29
# 50  package delivered payment reminder               i_29  payment reminder
#
#                        label           type  color intensity width  length  \
# 48                            visualization  black      None  None     1.0
# 49  freq = 1606 / dep = 1.00  visualization  black      None  None     4.0
# 50                            visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 48           start  False       items
# 49          middle  False       items
# 50             end   True       items
#
#
#                original_edge     source          target  \
# 51  pay order create package  pay order            o_18
# 52  pay order create package       o_18            i_17
# 53  pay order create package       i_17            i_20
# 54  pay order create package       i_20  create package
#
#                        label           type  color intensity width  length  \
# 51                            visualization  black      None  None     1.0
# 52  freq = 1064 / dep = 0.59  visualization  black      None  None     4.0
# 53                            visualization  black      None  None     1.0
# 54                            visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 51           start  False       items
# 52          middle  False       items
# 53      continue_i  False       items
# 54             end   True       items
#
#
#            original_edge     source     target                    label  \
# 127  pay order pay order  pay order       o_37
# 128  pay order pay order       o_37       i_43  freq = 922 / dep = 1.00
# 129  pay order pay order       i_43  pay order
#
#               type  color intensity width  length object_relation  arrow  \
# 127  visualization  black      None  None     1.0           start  False
# 128  visualization  black      None  None     4.0          middle  False
# 129  visualization  black      None  None     1.0             end   True
#
#     object_type
# 127    products
# 128    products
# 129    products
#
#
#                   original_edge            source     target  \
# 55   payment reminder pay order  payment reminder       o_25
# 56   payment reminder pay order              o_25       i_16
# 57   payment reminder pay order              i_16  pay order
# 101  payment reminder pay order  payment reminder       o_32
# 102  payment reminder pay order              o_32       i_36
# 103  payment reminder pay order              i_36  pay order
#
#                         label           type  color intensity width  length  \
# 55                             visualization  black      None  None     1.0
# 56   freq = 1669 / dep = 1.00  visualization  black      None  None     4.0
# 57                             visualization  black      None  None     1.0
# 101                            visualization  black      None  None     1.0
# 102   freq = 443 / dep = 1.00  visualization  black      None  None     4.0
# 103                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 55            start  False       items
# 56           middle  False       items
# 57              end   True       items
# 101           start  False      orders
# 102          middle  False      orders
# 103             end   True      orders
#
#
#                          original_edge            source            target  \
# 58   payment reminder payment reminder  payment reminder              o_26
# 59   payment reminder payment reminder              o_26              i_30
# 60   payment reminder payment reminder              i_30              i_28
# 61   payment reminder payment reminder              i_28  payment reminder
# 104  payment reminder payment reminder  payment reminder              o_33
# 105  payment reminder payment reminder              o_33              i_38
# 106  payment reminder payment reminder              i_38              i_39
# 107  payment reminder payment reminder              i_39  payment reminder
# 130  payment reminder payment reminder  payment reminder              o_44
# 131  payment reminder payment reminder              o_44              i_50
# 132  payment reminder payment reminder              i_50  payment reminder
#
#                        label           type  color intensity width  length  \
# 58                            visualization  black      None  None     1.0
# 59   freq = 468 / dep = 1.00  visualization  black      None  None     4.0
# 60                            visualization  black      None  None     1.0
# 61                            visualization  black      None  None     1.0
# 104                           visualization  black      None  None     1.0
# 105  freq = 123 / dep = 0.99  visualization  black      None  None     4.0
# 106                           visualization  black      None  None     1.0
# 107                           visualization  black      None  None     1.0
# 130                           visualization  black      None  None     1.0
# 131  freq = 258 / dep = 1.00  visualization  black      None  None     4.0
# 132                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 58            start  False       items
# 59           middle  False       items
# 60       continue_i  False       items
# 61              end   True       items
# 104           start  False      orders
# 105          middle  False      orders
# 106      continue_i  False      orders
# 107             end   True      orders
# 130           start  False    products
# 131          middle  False    products
# 132             end   True    products
#
#
#                original_edge     source          target  \
# 62  pick item create package  pick item            o_15
# 63  pick item create package       o_15            i_18
# 64  pick item create package       i_18            i_19
# 65  pick item create package       i_19  create package
#
#                        label           type  color intensity width  length  \
# 62                            visualization  black      None  None     1.0
# 63  freq = 5290 / dep = 0.98  visualization  black      None  None     4.0
# 64                            visualization  black      None  None     1.0
# 65                            visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 62           start  False       items
# 63          middle  False       items
# 64      continue_i  False       items
# 65             end   True       items
#
#
#            original_edge     source     target                     label  \
# 21   pick item pick item  pick item        o_3
# 22   pick item pick item        o_3        i_3  freq = 4545 / dep = 1.00
# 23   pick item pick item        i_3  pick item
# 133  pick item pick item  pick item       o_35
# 134  pick item pick item       o_35       i_41  freq = 1018 / dep = 1.00
# 135  pick item pick item       i_41  pick item
#
#               type  color intensity width  length object_relation  arrow  \
# 21   visualization  black      None  None     1.0           start  False
# 22   visualization  black      None  None     4.0          middle  False
# 23   visualization  black      None  None     1.0             end   True
# 133  visualization  black      None  None     1.0           start  False
# 134  visualization  black      None  None     4.0          middle  False
# 135  visualization  black      None  None     1.0             end   True
#
#     object_type
# 21    employees
# 22    employees
# 23    employees
# 133    products
# 134    products
# 135    products
#
#
#              original_edge     source        target                   label  \
# 66  pick item send package  pick item          o_16
# 67  pick item send package       o_16          i_23  freq = 57 / dep = 0.98
# 68  pick item send package       i_23  send package
#
#              type  color intensity width  length object_relation  arrow  \
# 66  visualization  black      None  None     1.0           start  False
# 67  visualization  black      None  None     4.0          middle  False
# 68  visualization  black      None  None     1.0             end   True
#
#    object_type
# 66       items
# 67       items
# 68       items
#
#
#                  original_edge       source         target  \
# 69   place order confirm order  place order           o_11
# 70   place order confirm order         o_11           o_13
# 71   place order confirm order         o_13           i_13
# 72   place order confirm order         i_13  confirm order
# 108  place order confirm order  place order           o_29
# 109  place order confirm order         o_29           i_34
# 110  place order confirm order         i_34  confirm order
#
#                         label           type  color intensity width  length  \
# 69                             visualization  black      None  None     1.0
# 70                             visualization  black      None  None     1.0
# 71   freq = 5232 / dep = 1.00  visualization  black      None  None     4.0
# 72                             visualization  black      None  None     1.0
# 108                            visualization  black      None  None     1.0
# 109  freq = 2000 / dep = 1.00  visualization  black      None  None     4.0
# 110                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 69            start  False       items
# 70       continue_o  False       items
# 71           middle  False       items
# 72              end   True       items
# 108           start  False      orders
# 109          middle  False      orders
# 110             end   True      orders
#
#
#                     original_edge       source             target  \
# 73  place order item out of stock  place order               o_14
# 74  place order item out of stock         o_14               i_26
# 75  place order item out of stock         i_26  item out of stock
#
#                       label           type  color intensity width  length  \
# 73                           visualization  black      None  None     1.0
# 74  freq = 495 / dep = 1.00  visualization  black      None  None     4.0
# 75                           visualization  black      None  None     1.0
#
#    object_relation  arrow object_type
# 73           start  False       items
# 74          middle  False       items
# 75             end   True       items
#
#
#             original_edge       source     target                     label  \
# 76  place order pick item  place order       o_12
# 77  place order pick item         o_12       i_11  freq = 1915 / dep = 1.00
# 78  place order pick item         i_11  pick item
#
#              type  color intensity width  length object_relation  arrow  \
# 76  visualization  black      None  None     1.0           start  False
# 77  visualization  black      None  None     4.0          middle  False
# 78  visualization  black      None  None     1.0             end   True
#
#    object_type
# 76       items
# 77       items
# 78       items
#
#
#                original_edge       source       target  \
# 3    place order place order  place order          o_1
# 4    place order place order          o_1          i_1
# 5    place order place order          i_1  place order
# 136  place order place order  place order         o_34
# 137  place order place order         o_34         i_40
# 138  place order place order         i_40  place order
#
#                        label           type  color intensity width  length  \
# 3                             visualization  black      None  None     1.0
# 4    freq = 505 / dep = 1.00  visualization  black      None  None     4.0
# 5                             visualization  black      None  None     1.0
# 136                           visualization  black      None  None     1.0
# 137  freq = 644 / dep = 1.00  visualization  black      None  None     4.0
# 138                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 3             start  False   customers
# 4            middle  False   customers
# 5               end   True   customers
# 136           start  False    products
# 137          middle  False    products
# 138             end   True    products
#
#
#              original_edge        source     target                    label  \
# 79  reorder item pick item  reorder item       o_24
# 80  reorder item pick item          o_24       i_12  freq = 869 / dep = 1.00
# 81  reorder item pick item          i_12  pick item
#
#              type  color intensity width  length object_relation  arrow  \
# 79  visualization  black      None  None     1.0           start  False
# 80  visualization  black      None  None     4.0          middle  False
# 81  visualization  black      None  None     1.0             end   True
#
#    object_type
# 79       items
# 80       items
# 81       items
#
#
#                  original_edge        source        target  \
# 24   reorder item reorder item  reorder item           o_4
# 25   reorder item reorder item           o_4           i_4
# 26   reorder item reorder item           i_4  reorder item
# 139  reorder item reorder item  reorder item          o_39
# 140  reorder item reorder item          o_39          i_45
# 141  reorder item reorder item          i_45  reorder item
#
#                        label           type  color intensity width  length  \
# 24                            visualization  black      None  None     1.0
# 25   freq = 194 / dep = 0.99  visualization  black      None  None     4.0
# 26                            visualization  black      None  None     1.0
# 139                           visualization  black      None  None     1.0
# 140   freq = 30 / dep = 0.97  visualization  black      None  None     4.0
# 141                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 24            start  False   employees
# 25           middle  False   employees
# 26              end   True   employees
# 139           start  False    products
# 140          middle  False    products
# 141             end   True    products
#
#
#                     original_edge        source           target  \
# 82   send package failed delivery  send package             o_21
# 83   send package failed delivery          o_21             i_32
# 84   send package failed delivery          i_32  failed delivery
# 151  send package failed delivery  send package             o_47
# 152  send package failed delivery          o_47             i_54
# 153  send package failed delivery          i_54  failed delivery
#
#                         label           type  color intensity width  length  \
# 82                             visualization  black      None  None     1.0
# 83   freq = 1270 / dep = 1.00  visualization  black      None  None     4.0
# 84                             visualization  black      None  None     1.0
# 151                            visualization  black      None  None     1.0
# 152   freq = 214 / dep = 1.00  visualization  black      None  None     4.0
# 153                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 82            start  False       items
# 83           middle  False       items
# 84              end   True       items
# 151           start  False    packages
# 152          middle  False    packages
# 153             end   True    packages
#
#
#                       original_edge        source             target  \
# 85   send package package delivered  send package               o_20
# 86   send package package delivered          o_20               i_24
# 87   send package package delivered          i_24  package delivered
# 154  send package package delivered  send package               o_46
# 155  send package package delivered          o_46               i_52
# 156  send package package delivered          i_52  package delivered
#
#                         label           type  color intensity width  length  \
# 85                             visualization  black      None  None     1.0
# 86   freq = 5917 / dep = 1.00  visualization  black      None  None     4.0
# 87                             visualization  black      None  None     1.0
# 154                            visualization  black      None  None     1.0
# 155   freq = 914 / dep = 1.00  visualization  black      None  None     4.0
# 156                            visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 85            start  False       items
# 86           middle  False       items
# 87              end   True       items
# 154           start  False    packages
# 155          middle  False    packages
# 156             end   True    packages
#
#
#                  original_edge        source        target  \
# 27   send package send package  send package           o_6
# 28   send package send package           o_6           i_6
# 29   send package send package           i_6  send package
# 142  send package send package  send package          o_41
# 143  send package send package          o_41          i_47
# 144  send package send package          i_47  send package
#
#                        label           type  color intensity width  length  \
# 27                            visualization  black      None  None     1.0
# 28   freq = 379 / dep = 1.00  visualization  black      None  None     4.0
# 29                            visualization  black      None  None     1.0
# 142                           visualization  black      None  None     1.0
# 143  freq = 557 / dep = 1.00  visualization  black      None  None     4.0
# 144                           visualization  black      None  None     1.0
#
#     object_relation  arrow object_type
# 27            start  False   employees
# 28           middle  False   employees
# 29              end   True   employees
# 142           start  False    products
# 143          middle  False    products
# 144             end   True    products

# %%
OCCN_model = all_ot_visualization(ot_activities, subgraphs, profile=['orders','items','packages'])
# Out:
# <view_occnets_jupyter.all_ot_visualization.<locals>.InteractiveSVG at 0x313402750>

# %% [markdown]
# Now, we illustrate how Causal nets for an object type are discovered. Here, we choose the object type 'items'. These are the activities related to this object type.

# %%
print(ot_activities['items'])

# %% [markdown]
# First, we flatten and read the log. This allows us to have all activities related to the object type identified by the 'item' object ID and discover their traces, which is the sequence of activities for each object in the log.

# %%
ocel, ot_activities, event_to_obj, obj_to_obj = import_log(file_path)
flt = flatten_log(ocel, ot_activities)
flt_items = flt['items']
logs = read_log(flt)
logs_items = logs['items']
all_traces = traces(flt)
ot_traces = all_traces['items']

# %% [markdown]
# Let us see how the trace for item 'i-880001' looks like.

# %%
print(ot_traces['i-880001'])

# %% [markdown]
# It shows all activities realized for item 'i-880001' in the order in which they happened, according to activity timestamps in the log. Next, we want to count some frequencies. As shown in the model, each activity has its corresponding total count. Also, the frequency one activity is followed by another activity is counted because it allows us to calculate the dependency measure between them. In addition, we discover the start and end activities for the object type 'items'.

# %%
act_total = activity_total(logs_items)
activities = activity_frequencies(logs_items)
or_start = original_start(act_total, activities)
or_end = original_end(act_total, activities)
freq = frequencies(activities)

# %% [markdown]
# Let us check how the frequency matrix for object type 'items' looks like.

# %%
print()
print('FREQUENCY MATRIX')
print()
print(freq)

# %% [markdown]
# Now, we can proceed to calculate the dependencies between activities. If only frequencies were considered, noise in the log could influence it, causing underfitting and admitting more behavior than it should in the model. However, the dependency measures prevent this from happening and are the fundamental variables on which Causal nets rely. We use three formulas to calculate the dependency measures. The first one relates two activities to one another; the second one relates one activity to itself (loops); and the third one relates two non-consecutive activities and helps determine if there is a long-distance causal relation between them. Let us see the dependency matrix for the object type 'items'.

# %%
dep = dependency_matrix(freq)
dep_dict = dependency_dict(dep)
long = long_distance_dependency(act_total, ot_traces, or_start, or_end)
print()
print('DEPENDENCY MATRIX')
print()
print(dep)

# %% [markdown]
# We consider a dependency measure of 0.95 or higher to build the dependency graph that serves as basis for the model. The dependency graph is composed of nodes and edges, where the nodes are the activities, and the edges are the arcs that connect one activity to another, showing the frequency and dependency relationships between them. When building the dependency graph, we need to avoid disconnected activities in the Causal nets model. This is achieved for each object type, but it is not always possible when there is more than one object type in the model because each object type has different start and end activities. To find the predecessor and successor activities of each activity, the dependency measure threshold is considered. This results in activities losing the race and potentially being disconnected in the Causal nets of an object type. To solve this, the next best predecessor is mined.

# %%
depgraph = dependency_graph(act_total, or_start, or_end, freq, dep, dep_dict, long, dependency_threshold=0.95)

# %% [markdown]
# Next, we use the dependency graph edges to discover the input and output arcs, that is, the predecessor and successor activities of each activity. By replaying the log in the arcs, we find the input and output bindings of each activity. This is the last step we need to take to discover the Causal nets of an object type.

# %%
# Generate the arcs based on the edges of the dep_graph
in_arcs = input_arcs(depgraph)
out_arcs = output_arcs(depgraph)

# Find the bindings in the incoming and outgoing arcs of the graph, using replay
cnet_outbindings = output_bindings(ot_traces, out_arcs, in_arcs)
cnet_inbindings = input_bindings(ot_traces, out_arcs, in_arcs)

# %% [markdown]
# Let us discover the Causal nets of the object type 'items'.

# %%
activity_counts, ot_counts, mean_dict, median_dict, min_dict, max_dict = ot_act_stats(event_to_obj)
ot_nodes, ot_edges, i_seq, o_seq = ot_graph(depgraph, act_total, act_total, ot_counts, mean_dict, median_dict, min_dict, max_dict, activities, dep_dict, cnet_inbindings, cnet_outbindings, seq_i=1, seq_o=1)
ot_subgraphs_dict = {'items': (ot_nodes, ot_edges)}
print(ot_subgraphs_dict)

# %% [markdown]
# However, this tabular representation is not ideal. So, in the next section, we will graphically visualize the complete model for selected object types.

# %% [markdown]
# ### Object-centric Model Visualization

# %% [markdown]
# We start by visualizing the 'items' object type Causal nets discovered in the previous section.

# %%
profile=['items']
cnets_items = all_ot_visualization(ot_activities, subgraphs, profile=profile)

# %% [markdown]
# However, in object-centric process mining, we are interested in the relationships between different object types. If all object types are included, the model can become cluttered and hinder the analysis. Thus, some object types are chosen, and their Causal nets are discovered and then merged to be presented in the model. The object types and respective activities for the current process are presented here.

# %%
for k,v in ot_activities.items():
    print(f"OT '{k}': activities {v}")  
print()

# %% [markdown]
# To generate the object-centric model, we can define a profile, which is the list of object types we select to include in the visualization. If not defined, the model will include all object types encountered in the OCEL file. In our case, the profile is ['items', 'packages']. Note that activities {'package delivered', 'send package', 'create package', 'failed delivery'} are common to both object types. This would result in more than one edge connecting two activities, one for each object type. To solve this, edges are merged to be represented in the model, and the frequency and dependency measures of one activity followed by another are shown in different colors assigned to each object type, for clarity. This is done only for single bindings, as explained in the paper. Next, the nodes of merged edges are removed from the graph in the algorithm. The final step is to generate the model and the legend for visualization. In our case, the chosen profile generates the following model.

# %%
profile = ['items', 'packages']

# %%
OCCN_model = all_ot_visualization(ot_activities, subgraphs, profile=profile)
