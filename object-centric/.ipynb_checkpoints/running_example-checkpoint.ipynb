# %% [markdown]
# ## Demonstrating Object-centric Causal nets by Merging Different Object Types C-nets with a Running Example

# %% [markdown]
# This notebook shows a running example of the discovery and visualization of an Object-centric Casual nets as presented in the paper 'Towards Discovering Object-centric Causal-Nets'.

# %% [markdown]
# ### Pre-requisites

# %% [markdown]
# Please install the libraries mentioned in the file requirements.txt
# You can do it by using pip install -r requirements.txt

# %%
import pm4py
# import processmining

from discover_occnets import *
from view_occnets_jupyter import *

# %%
file_path = './order-management.json'

# %% [markdown]
# ### Model Discovery

# %% [markdown]
# The approach introduced in the paper uses the discovery of Causal nets for each object type and then merges them. This running example is based on an order management process found in an OCEL 2.0 event log. First, let us view the process model when including all object types.

# %%
ot_activities, subgraphs = subgraphs_dict(file_path)

# %%
OCCN_model = all_ot_visualization(ot_activities, subgraphs, profile=None)
# Out:
# Warning: transparent is not a known color.

# %% [markdown]
# Now, we illustrate how to discover Causal nets for an object type. Here, we choose the object type 'items'. These are the activities related to this object type.

# %%
print(ot_activities['items'])
# Out:
# {'create package', 'payment reminder', 'failed delivery', 'pay order', 'pick item', 'reorder item', 'item out of stock', 'confirm order', 'package delivered', 'send package', 'place order'}

# %% [markdown]
# First, we flatten and read the log. This allows us to have all activities related to the object type identified by the 'item' object ID and discover their traces, which is the sequence of activities for each object in the log. Let us see what the trace for item 'i-880001' looks like.

# %%
ocel, ot_activities, event_to_obj, obj_to_obj = import_log(file_path)
flt = flatten_log(ocel, ot_activities)
flt_items = flt['items']
logs = read_log(flt)
logs_items = logs['items']
all_traces = traces(flt)
ot_traces = all_traces['items']

# %% [markdown]
# Let us see how the trace for item 'i-880001' looks like.

# %%
print(ot_traces['i-880001'])
# Out:
# ['place order', 'pick item', 'confirm order', 'pay order', 'create package', 'send package', 'package delivered']

# %% [markdown]
# It shows all activities realized for item 'i-880001' in the order in which they happened. This is possible due to activity timestamps in the log. Next, we want to count some frequencies. As shown in the model, each activity has its corresponding total count. Also, the frequency one activity is followed by another activity is counted because it allows us to calculate the dependency between them. In addition, we discover the start and end activities for the object type 'items'.

# %%
act_total = activity_total(logs['items'])
activities = activity_frequencies(logs_items)
or_start = original_start(act_total, activities)
or_end = original_end(act_total, activities)
freq = frequencies(activities)

# %% [markdown]
# Let us check how the frequency matrix for object type 'items' looks like.

# %%
print()
print('FREQUENCY MATRIX')
print()
print(freq)
# Out:
# FREQUENCY MATRIX
#
#                    pick item  confirm order  item out of stock  \
# place order           1915.0         5232.0              495.0
# pick item                0.0         1495.0                0.0
# confirm order         3528.0            0.0              895.0
# pay order             1236.0            0.0              154.0
# create package          66.0          215.0                0.0
# reorder item           869.0          166.0                0.0
# payment reminder        45.0            0.0                0.0
# send package             0.0          118.0                0.0
# package delivered        0.0          110.0                0.0
# item out of stock        0.0          319.0                0.0
# failed delivery          0.0            4.0                0.0
#
#                    create package  place order  pay order  send package  \
# place order                  17.0          0.0        0.0           0.0
# pick item                  5290.0          0.0      777.0          57.0
# confirm order              1254.0          0.0     1363.0         210.0
# pay order                  1064.0          0.0        0.0         286.0
# create package                0.0          0.0      272.0        7100.0
# reorder item                 10.0          0.0      438.0           0.0
# payment reminder             24.0          0.0     1669.0           6.0
# send package                  0.0          0.0      351.0           0.0
# package delivered             0.0          0.0     2562.0           0.0
# item out of stock             0.0          0.0      147.0           0.0
# failed delivery               0.0          0.0       80.0           0.0
#
#                    payment reminder  reorder item  package delivered  \
# place order                     0.0           0.0                0.0
# pick item                      40.0           0.0                0.0
# confirm order                  30.0         268.0               89.0
# pay order                       0.0         198.0              332.0
# create package                  6.0           0.0                0.0
# reorder item                   61.0           0.0                0.0
# payment reminder              468.0           0.0                2.0
# send package                    3.0           0.0             5917.0
# package delivered            1606.0           0.0                0.0
# item out of stock               0.0        1078.0                0.0
# failed delivery                 0.0           0.0             1319.0
#
#                    failed delivery
# place order                    0.0
# pick item                      0.0
# confirm order                 22.0
# pay order                    111.0
# create package                 0.0
# reorder item                   0.0
# payment reminder               0.0
# send package                1270.0
# package delivered              0.0
# item out of stock              0.0
# failed delivery              617.0

# %% [markdown]
# Now, we can proceed to calculate the dependencies between activities. If only frequency were considered, noise in the log could influence it, causing underfitting and admitting more behavior than it should in the model. However, the dependency measures prevent this from happening and are the fundamental variables on which Causal nets rely. We use three formulas to calculate the dependency measures. The first one relates two activities to one another; the second one relates one activity to itself (loops); and the third one relates two non-consecutive activities and helps determine if there is a long-distance causal relation between them. Let us see the dependency matrix for the object type 'items'.

# %%
dep = dependency_matrix(freq)
dep_dict = dependency_dict(dep)
long = long_distance_dependency(act_total, ot_traces, or_start, or_end)
print()
print('DEPENDENCY MATRIX')
print()
print(dep)
# Out:
# DEPENDENCY MATRIX
#
#                   pick item confirm order item out of stock create package  \
# place order        0.999478      0.999809          0.997984       0.944444
# pick item               0.0     -0.404658               0.0       0.975173
# confirm order      0.404658           0.0          0.474074       0.706803
# pay order          0.227905     -0.999267          0.023179       0.592371
# create package    -0.975173     -0.706803               0.0            0.0
# reorder item       0.998851     -0.234483         -0.999073       0.909091
# payment reminder    0.05814     -0.967742               0.0       0.580645
# send package      -0.982759     -0.279635               0.0      -0.999859
# package delivered       0.0         0.105               0.0            0.0
# item out of stock       0.0     -0.474074               0.0            0.0
# failed delivery         0.0     -0.666667               0.0            0.0
#
#                   place order pay order send package payment reminder  \
# place order               0.0       0.0          0.0              0.0
# pick item           -0.999478 -0.227905     0.982759         -0.05814
# confirm order       -0.999809  0.999267     0.279635         0.967742
# pay order                 0.0       0.0    -0.101881        -0.999401
# create package      -0.944444 -0.592371     0.999859        -0.580645
# reorder item              0.0  0.376766          0.0         0.983871
# payment reminder          0.0  0.999401          0.3         0.997868
# send package              0.0  0.101881          0.0             -0.3
# package delivered         0.0  0.770294    -0.999831         0.996892
# item out of stock   -0.997984 -0.023179          0.0              0.0
# failed delivery           0.0 -0.161458    -0.999213              0.0
#
#                   reorder item package delivered failed delivery
# place order                0.0               0.0             0.0
# pick item            -0.998851               0.0             0.0
# confirm order         0.234483            -0.105        0.666667
# pay order            -0.376766         -0.770294        0.161458
# create package       -0.909091               0.0             0.0
# reorder item               0.0               0.0             0.0
# payment reminder     -0.983871         -0.996892             0.0
# send package               0.0          0.999831        0.999213
# package delivered          0.0               0.0       -0.999242
# item out of stock     0.999073               0.0             0.0
# failed delivery            0.0          0.999242        0.998382

# %% [markdown]
# We consider a dependency measure of 0.95 or higher to build the dependency graph that serves as basis for the model. The dependency graph is composed of nodes and edges, where the nodes are the activities, and the edges are the arcs that connect one activity to another, showing the frequency and dependency relationships between them. When building the dependency graph, we need to avoid disconnected activities in the Causal nets model. This is achieved for each object type, but it is not always possible when there is more than one object type in the model because each object type has different start and end activities. To find the predecessor and successor activities of each activity, the dependency measure threshold is considered. This results in activities losing the race and potentially being disconnected in the Causal nets of an object type. To solve this, the next best predecessor is mined.

# %%
depgraph = dependency_graph(act_total, or_start, or_end, freq, dep, dep_dict, long, dependency_threshold=0.95)

# %% [markdown]
# Next, we use the dependency graph edges to discover the input and output arcs, that is, the predecessor and successor activities of each activity. By replaying the log in the arcs, we find the input and output bindings of each activity. This is the last step we need to take to discover the Causal nets of an object type.

# %%
# Generate the arcs based on the edges of the dep_graph
in_arcs = input_arcs(depgraph)
out_arcs = output_arcs(depgraph)

# Find the bindings in the incoming and outgoing arcs of the graph, using replay
cnet_outbindings = output_bindings(ot_traces, out_arcs, in_arcs)
cnet_inbindings = input_bindings(ot_traces, out_arcs, in_arcs)

# %% [markdown]
# Let us discover the Causal nets of the object type 'items'.

# %%
ot_nodes, ot_edges, i_seq, o_seq = ot_graph(depgraph, act_total, activities, dep_dict, cnet_inbindings, cnet_outbindings, seq_i=1, seq_o=1)
ot_subgraphs_dict = {'items': (ot_nodes, ot_edges)}
print(ot_subgraphs_dict)
# Out:
# {'items': (              node       type            source            target  \
# 0      place order   activity               NaN               NaN
# 1        pick item   activity               NaN               NaN
# 2    confirm order   activity               NaN               NaN
# 3        pay order   activity               NaN               NaN
# 4   create package   activity               NaN               NaN
# ..             ...        ...               ...               ...
# 57            i_26  inbinding  payment reminder  payment reminder
# 58            i_27  inbinding      reorder item  payment reminder
# 59            i_28  inbinding   failed delivery   failed delivery
# 60            i_29  inbinding      send package   failed delivery
# 61            i_30  inbinding   failed delivery   failed delivery
#
#                                             binding  len_binding  \
# 0                                               NaN          NaN
# 1                                               NaN          NaN
# 2                                               NaN          NaN
# 3                                               NaN          NaN
# 4                                               NaN          NaN
# ..                                              ...          ...
# 57  (confirm order, payment reminder, reorder item)          3.0
# 58  (confirm order, payment reminder, reorder item)          3.0
# 59                  (failed delivery, send package)          2.0
# 60                  (failed delivery, send package)          2.0
# 61                               (failed delivery,)          1.0
#
#                                                 label act_total    color  \
# 0   <<FONT>place order</FONT><BR/><FONT POINT-SIZE...      7659  #97c2fc
# 1   <<FONT>pick item</FONT><BR/><FONT POINT-SIZE="...      7659  #97c2fc
# 2   <<FONT>confirm order</FONT><BR/><FONT POINT-SI...      7659  #97c2fc
# 3   <<FONT>pay order</FONT><BR/><FONT POINT-SIZE="...      7659  #97c2fc
# 4   <<FONT>create package</FONT><BR/><FONT POINT-S...      7659  #97c2fc
# ..                                                ...       ...      ...
# 57                                               None       NaN    black
# 58                                               None       NaN    black
# 59                                               None       NaN    black
# 60                                               None       NaN    black
# 61                                               2020       NaN    black
#
#    intensity    shape  size                                     obj_group
# 0        NaN      box   2.0                                           NaN
# 1        NaN      box   2.0                                           NaN
# 2        NaN      box   2.0                                           NaN
# 3        NaN      box   2.0                                           NaN
# 4        NaN      box   2.0                                           NaN
# ..       ...      ...   ...                                           ...
# 57      None  diamond   0.7       out payment reminder - payment reminder
# 58      None  diamond   0.7           out payment reminder - reorder item
# 59      None  diamond   0.7         out failed delivery - failed delivery
# 60      None  diamond   0.7            out failed delivery - send package
# 61      None  diamond   0.7  out single failed delivery - failed delivery
#
# [62 rows x 13 columns],                      original_edge         source     target  \
# 0          confirm order pay order  confirm order        o_7
# 1          confirm order pay order            o_7        i_4
# 2          confirm order pay order            i_4  pay order
# 3   confirm order payment reminder  confirm order        o_8
# 4   confirm order payment reminder            o_8       i_21
# ..                             ...            ...        ...
# 79                            None           i_25       i_26
# 80                            None           i_25       i_27
# 81                            None           i_26       i_27
# 82                            None           i_19       i_20
# 83                            None           i_11       i_12
#
#                        label           type  color intensity width  length  \
# 0                             visualization  black      None  None     1.0
# 1   freq = 1363 / dep = 1.00  visualization  black      None  None     4.0
# 2                             visualization  black      None  None     1.0
# 3                             visualization  black      None  None     1.0
# 4     freq = 30 / dep = 0.97  visualization  black      None  None     4.0
# ..                       ...            ...    ...       ...   ...     ...
# 79                        65    vis_binding  black      None  None     NaN
# 80                        65    vis_binding  black      None  None     NaN
# 81                        65    vis_binding  black      None  None     NaN
# 82                       111    vis_binding  black      None  None     NaN
# 83                        66    vis_binding  black      None  None     NaN
#
#    object_relation  arrow
# 0            start  False
# 1           middle  False
# 2              end   True
# 3            start  False
# 4           middle  False
# ..             ...    ...
# 79       binding_i    NaN
# 80       binding_i    NaN
# 81       binding_i    NaN
# 82       binding_i    NaN
# 83       binding_i    NaN
#
# [84 rows x 11 columns])}

# %% [markdown]
# However, this tabular representation is not ideal. So, in the next section, we will graphically visualize the complete model for selected object types.

# %% [markdown]
# ### Model Visualization

# %% [markdown]
# We start by visualizing the 'items' object type Causal nets discovered in the previous section.

# %%
profile=['items']
cnets_items = all_ot_visualization(ot_activities, subgraphs, profile=profile)
# Out:
# Warning: transparent is not a known color.

# %% [markdown]
# However, in object-centric process mining, we are interested in the relationships between different object types. If all object types are included, the model can become cluttered and hinder the analysis. Thus, some object types are chosen, and their Causal nets are discovered and then merged to be presented in the model. The object types and respective activities for the current process are presented here.

# %%
for k,v in ot_activities.items():
    print(f"OT '{k}': activities {v}")  
print()
# Out:
# OT 'customers': activities {'place order', 'confirm order'}
# OT 'employees': activities {'create package', 'failed delivery', 'pick item', 'reorder item', 'item out of stock', 'confirm order', 'package delivered', 'send package'}
# OT 'items': activities {'create package', 'payment reminder', 'failed delivery', 'pay order', 'pick item', 'reorder item', 'item out of stock', 'confirm order', 'package delivered', 'send package', 'place order'}
# OT 'orders': activities {'pay order', 'payment reminder', 'confirm order', 'place order'}
# OT 'products': activities {'create package', 'payment reminder', 'failed delivery', 'pay order', 'pick item', 'reorder item', 'item out of stock', 'confirm order', 'package delivered', 'send package', 'place order'}
# OT 'packages': activities {'create package', 'failed delivery', 'package delivered', 'send package'}

# %% [markdown]
# To generate the model, we can define a profile, which is the list of object types we select to include in the visualization. If not defined, the model will include all object types encountered in the OCEL file. In our case, the profile is ['items', 'packages']. Note that activities {'package delivered', 'send package', 'create package', 'failed delivery'} are common to both object types. This would result in more than one edge connecting two activities, one for each object type. To solve this, edges are merged to be represented in the model, and the frequency and dependency measures of one activity followed by another are shown in different colors assigned to each object type, for clarity. This is done only for single bindings, as explained in the paper. Next, the nodes of merged edges are removed from the graph in the algorithm. The final step is to generate the model and the legend for visualization. In our case, the chosen profile generates the following model.

# %%
profile = ['items', 'packages']

# %%
OCCN_model = all_ot_visualization(ot_activities, subgraphs, profile=profile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 OCCN_model = all_ot_visualization(ot_activities, ot_seq, subgraphs, profile=profile)
#
# NameError: name 'ot_seq' is not defined
